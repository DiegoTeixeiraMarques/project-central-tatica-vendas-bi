# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoTeixeiraMarques/project-central-tatica-vendas-bi/blob/main/Mockar_dados_central_tatica_de_vendas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conectar com Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1. Carregar Dados

# %%
import pandas as pd
# Produtos
caminho_arquivo = '/content/drive/My Drive/Projetos/[PowerBI] Central de Vendas/dProdutos.xlsm'
dados = pd.read_excel(caminho_arquivo)
dados
# Out:
#           IdSku                                              NmSku  \
# 0          1933                      CHAPA CERAMICA PR BIV TAIFF .
# 1          2139                      PRAN TAIFF CER/ION LOOK BIV .
# 2          2197      AQUECEDOR OLEO BRITANIA AB1500 1.500W BR 110V
# 3          2202        MAQUINA P/PAO BRITANIA MULTI PANE 2 BR 110V
# 4          2203        MAQUINA P/PAO BRITANIA MULTI PANE 2 BR 220V
# ...         ...                                                ...
# 51278  55050331       TESOURA PARA COZINHA 8 POLEGADAS 20CM BRINOX
# 51279  55050332     TESOURA TRINCHANTE 10 POLEGADAS 25,5CM BRINOX.
# 51280  55054722  CAD DE ESCRITORIO OR DESIGN TOK BAIXA C RELAX BR.
# 51281  55054725   CAD DE ESCRITORIO OR DESIGN TOK BAIXA S RELAX BR
# 51282  55054727   CAD DE ESCRITORIO OR DESIGN TOK BAIXA S RELAX PT
#
#        IdCategoria             NmCategoria  IdMarca    NmMarca  \
# 0               46          BELEZA & SAUDE       31      TAIFF
# 1               46          BELEZA & SAUDE       31      TAIFF
# 2               28      SAZONAIS PORTATEIS      372   BRITANIA
# 3               21               PORTATEIS      372   BRITANIA
# 4               21               PORTATEIS      372   BRITANIA
# ...            ...                     ...      ...        ...
# 51278           22   UTILIDADES DOMESTICAS      178     BRINOX
# 51279           22   UTILIDADES DOMESTICAS      178     BRINOX
# 51280           64  MOVEIS PARA ESCRITORIO     2692  OR DESIGN
# 51281           64  MOVEIS PARA ESCRITORIO     2692  OR DESIGN
# 51282           64  MOVEIS PARA ESCRITORIO     2692  OR DESIGN
#
#         DtAtualizacaoRegistro  \
# 0     2022-11-09 14:18:27.057
# 1     2022-11-09 14:18:27.057
# 2     2022-11-09 14:18:27.057
# 3     2022-11-09 14:18:27.057
# 4     2022-11-09 14:18:27.057
# ...                       ...
# 51278 2022-11-16 03:06:33.170
# 51279 2022-11-16 03:06:33.170
# 51280 2022-11-16 03:06:33.170
# 51281 2022-11-16 03:06:33.170
# 51282 2022-11-16 03:06:33.170
#
#                                                  NmSkuId
# 0                   1933 | CHAPA CERAMICA PR BIV TAIFF .
# 1                   2139 | PRAN TAIFF CER/ION LOOK BIV .
# 2      2197 | AQUECEDOR OLEO BRITANIA AB1500 1.500W B...
# 3      2202 | MAQUINA P/PAO BRITANIA MULTI PANE 2 BR ...
# 4      2203 | MAQUINA P/PAO BRITANIA MULTI PANE 2 BR ...
# ...                                                  ...
# 51278  55050331 | TESOURA PARA COZINHA 8 POLEGADAS 20...
# 51279  55050332 | TESOURA TRINCHANTE 10 POLEGADAS 25,...
# 51280  55054722 | CAD DE ESCRITORIO OR DESIGN TOK BAI...
# 51281  55054725 | CAD DE ESCRITORIO OR DESIGN TOK BAI...
# 51282  55054727 | CAD DE ESCRITORIO OR DESIGN TOK BAI...
#
# [51283 rows x 8 columns]

# %%
dados.dtypes
# Out:
# IdSku                             int64
# NmSku                            object
# IdCategoria                       int64
# NmCategoria                      object
# IdMarca                           int64
# NmMarca                          object
# DtAtualizacaoRegistro    datetime64[ns]
# NmSkuId                          object
# dtype: object

# %%
def anonimizar_numero(codigo):
  return abs(int(((((codigo * 0.6) - 40) + 23) - 2) * 2.7))

# %%
list_idsku = dados['IdSku']

list_idsku[10]

for i in list_idsku:
  list_idsku[i] = anonimizar_numero(i)

list_idsku[10]
# Out:
# <ipython-input-59-1ac01e3ed795>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   list_idsku[i] = anonimizar_numero(i)
# 2294
